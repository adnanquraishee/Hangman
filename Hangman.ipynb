# %%
import random

# List of words for the game
words = ["python", "hangman", "computer", "programming", "gaming", "keyboard", "mouse", "monitor", "internet"]

def choose_word(words):
    return random.choice(words)

def display_word(word, guessed_letters):
    displayed_word = ""
    for letter in word:
        if letter in guessed_letters:
            displayed_word += letter
        else:
            displayed_word += "_"
    return displayed_word

def hangman():
    word = choose_word(words)
    guessed_letters = []
    max_attempts = 6
    attempts = 0

    print("Welcome to Hangman!")
    print("Try to guess the word.")

    while True:
        print("\n" + display_word(word, guessed_letters))

        guess = input("Enter a letter: ").lower()

        if guess in guessed_letters:
            print("You've already guessed that letter.")
            continue
        elif len(guess) != 1 or not guess.isalpha():
            print("Please enter a single letter.")
            continue

        guessed_letters.append(guess)

        if guess not in word:
            attempts += 1
            print("Incorrect guess. You have {} attempts left.".format(max_attempts - attempts))
            if attempts == max_attempts:
                print("You ran out of attempts! The word was '{}'.".format(word))
                break
        else:
            print("Correct guess!")

        if all(letter in guessed_letters for letter in word):
            print("\nCongratulations! You guessed the word '{}' correctly!".format(word))
            break

        # Draw hangman
        print("\n   _____")
        print("  |     |")
        print("  |     " + ("O" if attempts >= 1 else ""))
        print("  |    " + ("/" if attempts >= 2 else "") + ("|" if attempts >= 3 else "") + ("\\" if attempts >= 4 else ""))
        print("  |    " + ("/" if attempts >= 5 else "") + (" \\" if attempts >= 6 else ""))
        print("__|__")

        # Ask if the player wants to play again
        play_again = input("Do you want to play again? (yes/no): ").lower()
        if play_again != "yes":
            print("Thanks for playing!")
            break

hangman()
# Out:
# Welcome to Hangman!
# Try to guess the word.
#
# ______
# Enter a letter: a
# Correct guess!
#
#    _____
#   |     |
#   |
#   |
#   |
# __|__
# Do you want to play again? (yes/no): yes
#
# _a____
# Enter a letter: e
# Incorrect guess. You have 5 attempts left.
#
#    _____
#   |     |
#   |     O
#   |
#   |
# __|__
# Do you want to play again? (yes/no): yes
#
# _a____
# Enter a letter: r
# Incorrect guess. You have 4 attempts left.
#
#    _____
#   |     |
#   |     O
#   |    /
#   |
# __|__
# Do you want to play again? (yes/no): yes
#
# _a____
# Enter a letter: l
# Incorrect guess. You have 3 attempts left.
#
#    _____
#   |     |
#   |     O
#   |    /|
#   |
# __|__
# Do you want to play again? (yes/no): yes
#
# _a____
# Enter a letter: i
# Correct guess!
#
#    _____
#   |     |
#   |     O
#   |    /|
#   |
# __|__
# Do you want to play again? (yes/no): yes
#
# _a_i__
# Enter a letter: l
# You've already guessed that letter.
#
# _a_i__
# Enter a letter: t
# ...
